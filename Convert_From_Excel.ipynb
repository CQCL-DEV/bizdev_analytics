# %%
import pandas as pd
from openpyxl import load_workbook

# %%
master_sheet_df = pd.read_excel(r"C:\Users\dpomp\Downloads\Quantum Software Market Segmentation (1).xlsx", sheet_name="Master", header=0)

# %%
segmentation_all_df = pd.read_excel(r"C:\Users\dpomp\Downloads\Quantum Software Market Segmentation (1).xlsx", sheet_name="Segmentation ALL", header=0)

# %%
comp_companies_with_data = pd.merge(master_sheet_df, segmentation_all_df, left_on='Company', right_on='Company', how='left')

# %%
comp_companies_with_data.to_excel(r"C:\Users\dpomp\Downloads\Quantum Software Market Segmentation Merged.xlsx")

# %%
import os
import pandas as pd

# Specify the folder containing the CSV files
folder_path = r'C:\Users\dpomp\OneDrive\Documents\ZoomInfo-QC-companies'

# Get the list of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# Read and concatenate all CSV files into a single DataFrame
dataframes = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all DataFrames into one
combined_df = pd.concat(dataframes, ignore_index=True)

# Optional: save the concatenated DataFrame to a new CSV file
combined_df.to_excel(r'C:\Users\dpomp\Downloads\ZoomInfo-QC-All-companies.xlsx', index=False)

# %%
comp_companies_with_data
# Out:
#          #                                            Company      Industry  \
# 0      NaN                                                NaN           NaN
# 1      NaN  Green means we have worked with them and have ...           NaN
# 2      NaN  Light green means we havent worked with them b...           NaN
# 3      NaN  Yellow means we have worked with them but dont...           NaN
# 4      NaN  Blank means we havent worked with them and we ...           NaN
# ..     ...                                                ...           ...
# 926    NaN                                                NaN           NaN
# 927  335.0                                General Motors (GM)    Automotive
# 928    NaN                                                NaN           NaN
# 929  336.0                                             Triumf  National Lab
# 930    NaN                                                NaN           NaN
#
#       By Quantum Team Size Quantum Companies Engaged  \
# ...
