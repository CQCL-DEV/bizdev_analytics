# %%
from __future__ import print_function
import pandas as pd
import numpy as np
df = pd.read_excel("Downloads/Data_with_Master.xlsx")
df.head()
# Out:
#    Priority                 Company             Industry Region  \
# 0       1.0                     AGC             Chemical     JP
# 1       1.0  Air Force Research Lab        Public Sector    NaN
# 2       1.0  Air Force Research Lab                  NaN    NaN
# 3       1.0            Air Liquide              Chemical   EMEA
# 4       1.0                  Airbus  Aerospace & Defense    NaN
#
#    Previously Worked With Them  Open Opp   By Engaged with  \
# 0                          0.0       0.0   DM          NaN
# 1                          1.0       1.0  HD       QC Ware
# 2                          NaN       NaN  NaN   Quantinuum
# 3                          1.0       1.0   DM          IBM
# 4                          1.0       1.0  HD          IonQ
#
#                                     Area of Research  \
# 0                                                NaN
# 1   Identifying flight patterns of unmanned aircraft
# 2                                                NaN
# ...

# %%
df_report = pd.pivot_table(df, index=["Company", "Industry", "Region"], values=["Engaged with", "Link"],
                           aggfunc=[np.sum, np.mean], fill_value=0)
df_report.head()
# Out:
# C:\Users\dpomp\AppData\Local\Temp\ipykernel_15592\3420534853.py:1: FutureWarning: The operation <function mean at 0x000002A10D8BA940> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   df_report = pd.pivot_table(df, index=["Company", "Industry", "Region"], values=["Engaged with", "Link"],
#                                             sum  \
#                                    Engaged with
# Company Industry            Region
# ABB     Industrial          EMEA              0
# AGC     Chemical            JP                0
# AIS     Industrial          JP              IBM
# AWE     Aerospace & Defense EMEA              0
# AXA     Finance             EMEA              0
#
#
#                                                                     Link
# Company Industry            Region
# ABB     Industrial          EMEA                                       0
# ...

# %%
from jinja2 import Environment, FileSystemLoader
env = Environment(loader=FileSystemLoader('.'))
template = env.get_template("Downloads/competitor_report_template.html")

# %%
template_vars = {"title" : "Competitor Report - Company",
                 "national_pivot_table": df_report.to_html()}

# %%
html_out = template.render(template_vars)

# %%
import pdfkit

pdfkit.from_string(html_out, "competitor_report.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pdfkit\configuration.py:35, in Configuration.__init__(self, wkhtmltopdf, meta_tag_prefix, environ)
#      33     self.wkhtmltopdf = lines[0].strip()
# ---> 35 with open(self.wkhtmltopdf) as f:
#      36     pass
#
# FileNotFoundError: [Errno 2] No such file or directory: b''
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pdfkit
# ----> 3 pdfkit.from_string(html_out, "competitor_report.pdf")
#
# File ~\anaconda3\lib\site-packages\pdfkit\api.py:72, in from_string(input, output_path, options, toc, cover, css, configuration, cover_first, verbose)
#      54 def from_string(input, output_path=None, options=None, toc=None, cover=None, css=None,
# ...
